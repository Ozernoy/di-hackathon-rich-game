# %%
import requests


STOCK_API_KEY = "THQSP5BS8B7CGOYI" # https://www.alphavantage.co/documentation/

# %%
from alpha_vantage.timeseries import TimeSeries
ts = TimeSeries(key=STOCK_API_KEY, output_format='pandas')
# Get json object with the intraday data and another with  the call's metadata
data, meta_data = ts.get_intraday('GOOGL')

# %%
data
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2024-08-21 19:45:00  166.070  166.140  166.02   166.072     2616.0
# 2024-08-21 19:30:00  166.060  166.110  166.02   166.070     1760.0
# 2024-08-21 19:15:00  166.130  166.160  166.02   166.020     1651.0
# 2024-08-21 19:00:00  166.119  166.180  166.05   166.120     2391.0
# 2024-08-21 18:45:00  166.130  166.180  166.00   166.090     2398.0
# ...                      ...      ...     ...       ...        ...
# 2024-08-20 12:00:00  167.890  167.980  167.68   167.930   296558.0
# 2024-08-20 11:45:00  167.230  167.910  167.20   167.885   444287.0
# 2024-08-20 11:30:00  167.050  167.455  167.02   167.225   298351.0
# 2024-08-20 11:15:00  167.335  167.440  167.05   167.050   332728.0
# 2024-08-20 11:00:00  167.360  167.440  167.15   167.320   319062.0
#
# [100 rows x 5 columns]

# %%
url = f'https://www.alphavantage.co/query?function=HISTORICAL_OPTIONS&symbol=IBM&apikey={STOCK_API_KEY}'
r = requests.get(url)
data = r.json()

# %%
data['data']
# Out:
# [{'contractID': 'IBM240823C00095000',
#   'symbol': 'IBM',
#   'expiration': '2024-08-23',
#   'strike': '95.00',
#   'type': 'call',
#   'last': '0.00',
#   'mark': '102.28',
#   'bid': '101.00',
#   'bid_size': '36',
#   'ask': '103.55',
#   'ask_size': '41',
#   'volume': '0',
#   'open_interest': '0',
#   'date': '2024-08-21',
#   'implied_volatility': '3.68651',
#   'delta': '0.99755',
#   'gamma': '0.00014',
#   'theta': '-0.42402',
#   'vega': '0.00111',
#   'rho': '0.00518'},
#  {'contractID': 'IBM240823P00095000',
#   'symbol': 'IBM',
#   'expiration': '2024-08-23',
#   'strike': '95.00',
#   'type': 'put',
#   'last': '0.00',
#   'mark': '0.01',
#   'bid': '0.00',
#   'bid_size': '0',
#   'ask': '0.01',
#   'ask_size': '750',
#   'volume': '0',
#   'open_interest': '0',
#   'date': '2024-08-21',
#   'implied_volatility': '3.22509',
#   'delta': '-0.00074',
#   'gamma': '0.00005',
#   'theta': '-0.10907',
#   'vega': '0.00037',
#   'rho': '-0.00001'},
# ...

# %%
symbol = 'AAPL'

url = f'https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY_ADJUSTED&symbol={symbol}&apikey={STOCK_API_KEY}'

response = requests.get(url)

data = response.json()

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from
